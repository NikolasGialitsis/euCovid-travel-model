# %%
# !git clone https://github.com/NikolasGialitsis/euCovid-travel-model
# Out:
# Cloning into 'euCovid-travel-model'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 99 (delta 22), reused 69 (delta 7), pack-reused 0
# Unpacking objects: 100% (99/99), done.

# %%
# !pip install python-copasi
# %cd /content/euCovid-travel-model/generating
# Out:
# Collecting python-copasi
#   Downloading https://files.pythonhosted.org/packages/e3/c3/67d338d0869ebeca278171710c82d03365f4247e036fe329f26db4e5e225/python_copasi-4.28.226-cp36-cp36m-manylinux1_x86_64.whl (9.7MB)
#      |████████████████████████████████| 9.7MB 2.7MB/s
# Installing collected packages: python-copasi
# Successfully installed python-copasi-4.28.226
# [Errno 2] No such file or directory: '/content/euCovid-travel-model/generating'
# /content

# %%
# !mv /content/euCovid-travel-model/EU_expand_model.py /content/euCovid-travel-model/generating

# %%
# !python /content/euCovid-travel-model/expand_model.py /content/euCovid-travel-model/generating/SEIR_base.cps eu_usa.cps
# Out:
# abrev: {'GR': 0, 'IT': 1, 'BU': 2}
# tcmalloc: large alloc 1449377792 bytes == 0x2ddc000 @  0x7f4188652001 0x582743 0x582af3 0x50d164 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f418824db97 0x5b250a
# compartment name =  COVID_GR
# state_abrev =  GR
# GR 0
# state flux =  [{0: 0.1, 1: 0.005, 2: 0.01}, {0: 0.1, 1: 0.0001, 2: 0.002}]
# compartment name =  COVID_IT
# state_abrev =  IT
# IT 1
# state flux =  [{0: 0.0001, 1: 0.02, 2: 0.0025}, {0: 0.005, 1: 0.02, 2: 0.0005}]
# compartment name =  COVID_BU
# state_abrev =  BU
# BU 2
# state flux =  [{0: 0.002, 1: 0.0005, 2: 0.006666666666666667}, {0: 0.01, 1: 0.0025, 2: 0.006666666666666667}]
# Number of assigments = 12
#
# Number of assigments = 12

# %%
# %cd /content/
# !kaggle datasets download -d shahules/european-countries-population
# Out:
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
import os
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from random import sample 
from google.colab import drive

def bash_collect_data():
  sys.path.append('/usr/local/lib/python3.7/site-packages/')
  drive.mount('/content/drive')
  os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/Colab Notebooks/.kaggle/"
  # !kaggle datasets download -d datagraver/eurovision-song-contest-scores-19752019
  # !kaggle datasets download -d sudalairajkumar/novel-corona-virus-2019-dataset
  # !kaggle datasets download -d duvallwh/us-asia-and-europe-population-and-area-data
  # !unzip /content/european-countries-population.zip
  # !unzip /content/novel-corona-virus-2019-dataset.zip
  # !unzip /content/us-asia-and-europe-population-and-area-data.zip
  # !unzip datasets download -d datagraver/eurovision-song-contest-scores-19752019

def PopsAreas2dict(fn='/content/area_pop_data.csv'):
    df = pd.read_csv(fn)
    df = df[df['region'] == 'Europe']
    print(df.columns)
    areas = {}
    pops = {}
    for row in df.iterrows():
      name = row[1]['country'].upper()
      name = name.split(' ')[0]
      area = row[1]['area_km']
      pop = row[1]['population']
      if name not in areas.keys():
        areas[name] = area
        pops[name] = pop
      else:
        areas[name] += area 
        pops[name] += pop
    return pops,areas

def CovidCountry(fn,countries):
  df = pd.read_csv(fn)
  df = df.drop(labels=['Lat','Long'],axis='columns')
  df['lastmonth'] = df[df.columns[-30:]].sum(axis=1) 
  infected = {}
  for row in df.iterrows():
    name = row[1]['Country/Region'].upper()
    name = name.split(' ')[0]
    confirmed = row[1]['lastmonth']
    if name not in countries:
      continue
    if name not in infected.keys():
      infected[name] = confirmed
    else:
      infected[name] += confirmed
  return infected

def getEurovision(fn,countries):
  df = pd.read_excel(fn) 
  FromDict = {}
  ToDict = {}
  
  for row in df.iterrows():
    n_from = row[1]['From country'].upper()
    n_to = row[1]['To country'].upper()
    if n_from not in countries or n_to not in countries:
      continue
    points =  row[1]['Points      ']
    if n_from not in FromDict.keys():
      FromDict[n_from] = {n_to:points}
    else:
      if n_to in FromDict[n_from].keys():
        FromDict[n_from][n_to] += points
      else:
        FromDict[n_from][n_to] = points

    if n_to not in ToDict.keys():
      ToDict[n_to] = {n_from:points}
    else:
      if n_from in ToDict[n_to].keys():
        ToDict[n_to][n_from] += points
      else:
        ToDict[n_to][n_from] = points 
  for key in FromDict:
    total = sum([x for x in FromDict[key].values()])
    FromDict[key] = {k: v / total for k, v in FromDict[key].items()}
  for key in ToDict:
    total = sum([x for x in ToDict[key].values()])
    ToDict[key] = {k: v / total for k, v in ToDict[key].items()}
  
  
  for country in EUcountries:
    if country not in FromDict.keys():
      FromDict[country] = {}
    if country not in ToDict.keys():
      ToDict[country] = {}

  for source in FromDict.keys():
    for target in EUcountries:
      if target not in FromDict[source].keys():
        FromDict[source][target] = 0.0
  for source in ToDict.keys():
    for target in EUcountries:
      if target not in ToDict[source].keys():
        ToDict[source][target] = 0.0 
      
  return FromDict,ToDict

def getFluxes(FromDict,ToDict,Pops):
  Fluxes = {}
  for country in FromDict.keys():
    ToDict[country] = {k: v * Pops[country] for k, v in ToDict[country].items()}
    FromDict[country] = {k: v * Pops[country] for k, v in FromDict[country].items()}
    Fluxes[country] = [FromDict[country],ToDict[country]]
  return Fluxes


#bash_collect_data()
#!unzip /content/eurovision-song-contest-scores-19752019.zip
pops,areas =  PopsAreas2dict('/content/area_pop_data.csv')

EUcountries = pops.keys()
print(pops.keys())
infected = CovidCountry(fn='/content/time_series_covid_19_confirmed.csv',countries=EUcountries)
FromDict,ToDict = getEurovision('/content/eurovision_song_contest_1975_2019.xlsx',EUcountries)
Fluxes = getFluxes(FromDict,ToDict,pops)
# Out:
# Index(['Unnamed: 0', 'region', 'country', 'province', 'area_km', 'population'], dtype='object')
# dict_keys(['ALBANIA', 'ANDORRA', 'ARMENIA', 'AUSTRIA', 'AZERBAIJAN', 'BELARUS', 'BELGIUM', 'BOSNIA', 'BULGARIA', 'CROATIA', 'CYPRUS', 'CZECH', 'DENMARK', 'ESTONIA', 'FAROE', 'FINLAND', 'FRANCE', 'GEORGIA', 'GERMANY', 'GIBRALTAR', 'GREECE', 'GUERNSEY', 'HUNGARY', 'ICELAND', 'REPUBLIC', 'ISLE', 'ITALY', 'JERSEY', 'KAZAKHSTAN', 'KOSOVO', 'LATVIA', 'LIECHTENSTEIN', 'LITHUANIA', 'LUXEMBOURG', 'MALTA', 'MOLDOVA', 'MONACO', 'MONTENEGRO', 'NETHERLANDS', 'NORTH', 'NORWAY', 'POLAND', 'PORTUGAL', 'ROMANIA', 'RUSSIA', 'SAN', 'SERBIA', 'SLOVAKIA', 'SLOVENIA', 'SPAIN', 'MAYEN', 'SWEDEN', 'SWITZERLAND', 'TRANSNISTRIA', 'TURKEY', 'UKRAINE', 'UNITED', 'VATICAN', 'ÅLAND'])

# %%
  
  #US_states = make_model.process_travel_data.stateKeysLoad('travel_data/state_county_FIPS.csv')
  US_states = {0:'GR',1:'IT',2:'BU'}
  id = 0
  US_states = {}
  for country in EUcountries:
    US_states[country] = country


  #US_state_populations = make_model.process_travel_data.statePopsLoad('travel_data/countypops_2013.csv')
  US_state_populations = pops

  #US_state_land_areas = make_model.process_travel_data.stateAreasLoad('state_land_area.txt')
  US_state_land_areas = areas
  
  # Only model states which have population data and land area
  #US_states = {key: value for (key, value) in US_states.items() if key in US_state_populations and value in US_state_land_areas}

  # Get the reverse mapping
  state_abrev_to_key = {value: value for value in EUcountries}
  # Get the state-centric flows in and out
  #state_fluxes = make_model.process_travel_data.makeStateFluxes('travel_data/commute_flow_counts.csv')
  
  #[IN,OUT]

  state_fluxes = Fluxes.copy()

# %% [markdown]
# !

# %%
#!/usr/bin/env python
import COPASI
#import make_model.process_travel_data
import sys

def expand_model(input_file_path, output_file_path):
  """expands the model in the given file."""

  assert COPASI.CRootContainer.getRoot() != None
  # create a new datamodel
  dataModel = COPASI.CRootContainer.addDatamodel()
  assert COPASI.CRootContainer.getDatamodelList().size() == 1
  
  # load the base model
  dataModel.loadModel(input_file_path)
  
  # get the model from the datamodel
  model = dataModel.getModel()
  assert model != None
  
  modelName = 'SEIR State Travel'
  
  model.setObjectName(modelName)
  

  home_to_work_event = model.createEvent('home to work event')
  home_to_work_trigger_expression = 'sin(2*pi*<CN=Root,Model={0},Reference=Time>) > 0'.format(modelName)
  home_to_work_event.setTriggerExpression(home_to_work_trigger_expression)
  work_to_home_event = model.createEvent('work to home event')
  work_to_home_trigger_expression = 'sin(2*pi*(<CN=Root,Model={0},Reference=Time>+0.34)) > 0'.format(modelName)
  work_to_home_event.setTriggerExpression(work_to_home_trigger_expression)
  
  
  modelElementsToExpand = COPASI.CModelExpansion_SetOfModelElements()
  compartmentToReplicate = model.getCompartment(0)
  
  compartmentToReplicate.setObjectName('COVID')
  
  metabsToReplicate = {metab.getObjectName(): metab for metab in model.getMetabolites()}
  
  reactionsToReplicate = [reac for reac in model.getReactions()]
  
  flow_weight_template = '({0}*<{1}>/<{2}>)'
  
  total_adj_flow_template = '({0})/{1}'
  
  # Map of compartment species to CN, for use in event assignment creation
  comp_metab_CN = dict()
  
  # Make something to iterate over for event assignments, which with also have US_state_keys
  compartment_names_new = dict()
  
  # Map for the state keys to the new compartment names
  US_state_key_to_comp = dict()
  
  # Create all the replicate compartments (and species and reactions)
  for US_state_key, US_state_abrev in US_states.items():
  
      # need an empty elements map, each time
      elementsMap = COPASI.CModelExpansion_ElementsMap()
      modelElementsToExpand.addCompartment(compartmentToReplicate)
  
      for metab in metabsToReplicate.values():
          modelElementsToExpand.addMetab(metab)
          
      for reaction in reactionsToReplicate:
          modelElementsToExpand.addReaction(reaction)
  
      modelElementsToExpand.fillDependencies(model)
      expansion = COPASI.CModelExpansion(model)
      expansion.duplicate(modelElementsToExpand, '_' + US_state_abrev, elementsMap)
  
      # Get the new metabs, for use below
      metabs = {name: elementsMap.getDuplicateFromObject(metabsToReplicate[name]) for name in metabsToReplicate.keys()}
  
      # change the particle numbers for the copied 'S' and 'N', to the given US state's population
      metabs['S'].setInitialValue(US_state_populations[US_state_key])
      metabs['N'].setInitialValue(US_state_populations[US_state_key])
  
      # set the compartment area to that of the state land area
      this_state_area = US_state_land_areas[US_state_abrev]
      elementsMap.getDuplicateFromObject(compartmentToReplicate).setInitialValue(this_state_area)
  
      # Add this (keyed) compartment name, for use in building event assignments
      compartment_name_new = elementsMap.getDuplicateFromObject(compartmentToReplicate).getObjectName()
      compartment_names_new[US_state_key] = compartment_name_new
  
      # Add the new CNs to the compartment+metab to ValueReference CN mapping
      for metab_name, metab in metabsToReplicate.items():
          comp_metab_CN[(compartment_name_new, metab_name)] = elementsMap.getDuplicateFromObject(metab).getValueReference().getCN()
  
  # Build the event assignments
  for compartment_name in compartment_names_new.values():
  
      # Need the actual compartment metabs, because the metab concentration, not the particle number, needs to be the target
      compartment = model.getCompartments().getByName(compartment_name)
      compartment_metabs = compartment.getMetabolites()
  
      # Grab the land area, for use in creating the target as a concentration
      land_area = compartment.getInitialValue()
  
      # Work-around to match compartment names generated by CModelExpansionDuplicate to ones pulled in from the US_states
      
      state_abrev = compartment_name.replace(compartmentToReplicate.getObjectName() + '_', '') 
      print('compartment name = ',compartment_name)
      # Load the data about how many move in and out
      print('state_abrev = ',state_abrev)
      state_flux = state_fluxes[state_abrev_to_key[state_abrev]]
      
      print(state_abrev,state_abrev_to_key[state_abrev])
      print('state flux = ',state_flux)
      # Create assignment objects for all but the 'N' species
      #    event_assignments = {metab_name: movement_event.createAssignment() for metab_name in metabsToReplicate.keys() if metab_name is not 'N'}
  
  
  
      N_val_CN = comp_metab_CN[(compartment_name, 'N')]
  
      for metab_name in metabsToReplicate.keys():
          if metab_name is 'N':
              continue
          metab = compartment_metabs.getByName(metab_name)
          metab_val_CN = comp_metab_CN[(compartment_name, metab_name)]
      
          # Morning commute event flows
          # Build the list of morning event in-flow terms to string join
          inTermListMorning = list()
          inTermListMorning.append('<' + str(metab_val_CN) + '>') # particles before change
          for state_key, inFlow in state_flux[0].items():
              name_compartment_from = compartment_names_new[state_key]
              this_N_val_CN = comp_metab_CN[(name_compartment_from, 'N')]
              this_metab_val_CN = comp_metab_CN[(name_compartment_from, metab_name)]
              inTerm = flow_weight_template.format(str(inFlow), str(this_metab_val_CN),str(this_N_val_CN))
              inTermListMorning.append(inTerm)
  

          # Build the list of morning event out-flow terms to string join
          outTermListMorning = list()
          for state_key, outFlow in state_flux[1].items():
              outTerm = flow_weight_template.format(str(outFlow), str(metab_val_CN),str(N_val_CN))
              outTermListMorning.append(outTerm)
  

          flow_terms_morning = '+'.join(inTermListMorning) + '-' + '-'.join(outTermListMorning)
          full_expression_morning = total_adj_flow_template.format(flow_terms_morning, land_area)
 
          assignmentMorning = home_to_work_event.createAssignment()
          assignmentMorning.setTargetCN(metab.getCN())
          assignmentMorning.setExpression(full_expression_morning)

          # Evening return from work event flows
          # Build the list of evening event in-flow terms to string join
          inTermListEvening = list()
          inTermListEvening.append('<' + str(metab_val_CN) + '>') # particles before change
          for state_key, inFlow in state_flux[1].items():
              name_compartment_from = compartment_names_new[state_key]
              this_N_val_CN = comp_metab_CN[(name_compartment_from, 'N')]
              this_metab_val_CN = comp_metab_CN[(name_compartment_from, metab_name)]
              inTerm = flow_weight_template.format(str(inFlow), str(this_metab_val_CN),str(this_N_val_CN))
              inTermListEvening.append(inTerm)
  

          # Build the list of evening event out-flow terms to string join
          outTermListEvening = list()
          for state_key, outFlow in state_flux[0].items():
              outTerm = flow_weight_template.format(str(outFlow), str(metab_val_CN),str(N_val_CN))
              outTermListEvening.append(outTerm)
  

          flow_terms_evening = '+'.join(inTermListEvening) + '-' + '-'.join(outTermListEvening)
          full_expression_evening = total_adj_flow_template.format(flow_terms_evening, land_area)
 
          assignmentEvening = work_to_home_event.createAssignment()
          assignmentEvening.setTargetCN(metab.getCN())
          assignmentEvening.setExpression(full_expression_evening)
  
  print('Number of assigments = ' + str(home_to_work_event.getAssignments().size()) + '\n')
  print('Number of assigments = ' + str(work_to_home_event.getAssignments().size()) + '\n')
  
  model.forceCompile()
  
  dataModel.saveModel(output_file_path, True)


if __name__ == "__main__": 
  # %cd /content/euCovid-travel-model/generating
  input = '/content/euCovid-travel-model/generating/SEIR_base.cps'
  output = 'eurocovid2020.cps'
  print('expanding model')
  expand_model(input,output)

main()
# Out:
# /content/euCovid-travel-model/generating
# expanding model
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-113-f72763d3b227> in <module>()
#     188   output = 'eurocovid2020.cps'
#     189   print('expanding model')
# --> 190   expand_model(input,output)
#     191
#     192 main()
#
# <ipython-input-113-f72763d3b227> in expand_model(input_file_path, output_file_path)
#      10   # create a new datamodel
#      11   dataModel = COPASI.CRootContainer.addDatamodel()
# ---> 12   assert COPASI.CRootContainer.getDatamodelList().size() == 1
#      13
#      14   # load the base model
#
# AssertionError:

# %%
# !python /content/euCovid-travel-model/expand_model.py /content/euCovid-travel-model/generating/SEIR_base.cps eurocovid2020.cps
# Out:
# Index(['Unnamed: 0', 'region', 'country', 'province', 'area_km', 'population'], dtype='object')
# dict_keys(['ALBANIA', 'ANDORRA', 'ARMENIA', 'AUSTRIA', 'AZERBAIJAN', 'BELARUS', 'BELGIUM', 'BOSNIA', 'BULGARIA', 'CROATIA', 'CYPRUS', 'CZECH', 'DENMARK', 'ESTONIA', 'FAROE', 'FINLAND', 'FRANCE', 'GEORGIA', 'GERMANY', 'GIBRALTAR', 'GREECE', 'GUERNSEY', 'HUNGARY', 'ICELAND', 'REPUBLIC', 'ISLE', 'ITALY', 'JERSEY', 'KAZAKHSTAN', 'KOSOVO', 'LATVIA', 'LIECHTENSTEIN', 'LITHUANIA', 'LUXEMBOURG', 'MALTA', 'MOLDOVA', 'MONACO', 'MONTENEGRO', 'NETHERLANDS', 'NORTH', 'NORWAY', 'POLAND', 'PORTUGAL', 'ROMANIA', 'RUSSIA', 'SAN', 'SERBIA', 'SLOVAKIA', 'SLOVENIA', 'SPAIN', 'MAYEN', 'SWEDEN', 'SWITZERLAND', 'TRANSNISTRIA', 'TURKEY', 'UKRAINE', 'UNITED', 'VATICAN', 'ÅLAND'])
# compartment name =  COVID_ALBANIA
# state_abrev =  ALBANIA
# ALBANIA ALBANIA
# state flux =  [{'ALBANIA': 0.0, 'AUSTRIA': 23920.00278551532, 'BELGIUM': 66976.0077994429, 'CROATIA': 60597.340389972145, 'CYPRUS': 138736.01615598885, 'FRANCE': 65381.34094707521, 'GERMANY': 78138.6757660167, 'GREECE': 366773.37604456826, 'ICELAND': 36677.33760445682, 'MALTA': 81328.00947075209, 'NORWAY': 86112.01002785515, 'POLAND': 36677.33760445682, 'ROMANIA': 66976.0077994429, 'RUSSIA': 113221.34651810586, 'SPAIN': 87706.67688022283, 'SWEDEN': 141925.34986072424, 'TURKEY': 180197.35431754877, 'UKRAINE': 60597.340389972145, 'ANDORRA': 9568.001114206128, 'BELARUS': 20730.669080779942, 'DENMARK': 27109.3364902507, 'ESTONIA': 25514.66963788301, 'FINLAND': 35082.670752089136, 'LATVIA': 1594.666852367688, 'LITHUANIA': 22325.33593314763, 'MONACO': 3189.333704735376, 'PORTUGAL': 76544.00891364903, 'SLOVENIA': 38272.004456824514, 'SWITZERLAND': 73354.67520891364, 'HUNGARY': 94085.3442896936, 'MOLDOVA': 59002.67353760446, 'BULGARIA': 140330.68300835654, 'ARMENIA': 54218.6729805014, 'GEORGIA': 7973.33426183844, 'SERBIA': 49434.67242339833, 'MONTENEGRO': 68570.67465181058, 'AZERBAIJAN': 146709.35041782729, 'SLOVAKIA': 6378.667409470752, 'ITALY': 210496.02451253482, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 11388.966843501326, 'AUSTRIA': 113889.66843501326, 'BELARUS': 45555.867374005305, 'BELGIUM': 119584.15185676393, 'CROATIA': 187917.95291777188, 'CYPRUS': 56944.83421750663, 'DENMARK': 58842.995358090186, 'ESTONIA': 5694.483421750663, 'FINLAND': 58842.995358090186, 'FRANCE': 39861.38395225464, 'GERMANY': 58842.995358090186, 'GREECE': 391021.1949602122, 'ICELAND': 96806.21816976128, 'LATVIA': 20879.7725464191, 'LITHUANIA': 1898.1611405835542, 'MALTA': 51250.35079575597, 'MONACO': 5694.483421750663, 'NORWAY': 39861.38395225464, 'POLAND': 36065.06167108753, 'PORTUGAL': 43657.70623342175, 'ROMANIA': 37963.22281167109, 'RUSSIA': 36065.06167108753, 'SLOVENIA': 66435.63992042441, 'SPAIN': 47454.02851458886, 'SWEDEN': 51250.35079575597, 'SWITZERLAND': 303705.7824933687, 'TURKEY': 113889.66843501326, 'UKRAINE': 13287.12798408488, 'BULGARIA': 39861.38395225464, 'HUNGARY': 66435.63992042441, 'MOLDOVA': 45555.867374005305, 'ARMENIA': 11388.966843501326, 'GEORGIA': 24676.094827586207, 'MONTENEGRO': 229677.49801061006, 'SERBIA': 22777.933687002653, 'AZERBAIJAN': 136667.6021220159, 'SLOVAKIA': 7592.644562334217, 'ITALY': 163241.85809018568, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_ANDORRA
# state_abrev =  ANDORRA
# ANDORRA ANDORRA
# state flux =  [{'ALBANIA': 831.4201954397394, 'AUSTRIA': 1108.5602605863194, 'BELGIUM': 1108.5602605863194, 'CROATIA': 0.0, 'CYPRUS': 831.4201954397394, 'FRANCE': 3602.820846905537, 'GERMANY': 692.8501628664495, 'GREECE': 4711.381107491857, 'ICELAND': 3325.6807817589574, 'MALTA': 2494.260586319218, 'NORWAY': 3602.820846905537, 'POLAND': 1385.700325732899, 'ROMANIA': 4711.381107491857, 'RUSSIA': 3048.540716612378, 'SPAIN': 8314.201954397395, 'SWEDEN': 4434.2410423452775, 'TURKEY': 2078.5504885993487, 'UKRAINE': 6789.9315960912045, 'ANDORRA': 0.0, 'BELARUS': 0.0, 'DENMARK': 2494.260586319218, 'ESTONIA': 0.0, 'FINLAND': 6789.9315960912045, 'LATVIA': 1662.8403908794787, 'LITHUANIA': 1801.4104234527686, 'MONACO': 2355.6905537459284, 'PORTUGAL': 8868.482084690555, 'SLOVENIA': 1108.5602605863194, 'SWITZERLAND': 1247.130293159609, 'HUNGARY': 2355.6905537459284, 'MOLDOVA': 692.8501628664495, 'BULGARIA': 0.0, 'ARMENIA': 415.7100977198697, 'GEORGIA': 0.0, 'SERBIA': 0.0, 'MONTENEGRO': 138.57003257328992, 'AZERBAIJAN': 2078.5504885993487, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'SLOVAKIA': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 3896.885496183206, 'ANDORRA': 0.0, 'AUSTRIA': 0.0, 'BELARUS': 2597.9236641221373, 'BELGIUM': 0.0, 'CROATIA': 1298.9618320610687, 'CYPRUS': 0.0, 'DENMARK': 0.0, 'ESTONIA': 5195.847328244275, 'FINLAND': 3247.4045801526718, 'FRANCE': 0.0, 'GERMANY': 0.0, 'GREECE': 2597.9236641221373, 'ICELAND': 3896.885496183206, 'LATVIA': 0.0, 'LITHUANIA': 1298.9618320610687, 'MALTA': 1948.442748091603, 'MONACO': 0.0, 'NORWAY': 1298.9618320610687, 'POLAND': 4546.366412213741, 'PORTUGAL': 6494.8091603053435, 'ROMANIA': 0.0, 'RUSSIA': 2597.9236641221373, 'SLOVENIA': 3247.4045801526718, 'SPAIN': 35071.96946564886, 'SWEDEN': 1298.9618320610687, 'SWITZERLAND': 0.0, 'TURKEY': 1948.442748091603, 'UKRAINE': 0.0, 'BULGARIA': 0.0, 'HUNGARY': 0.0, 'MOLDOVA': 2597.9236641221373, 'ARMENIA': 0.0, 'GEORGIA': 0.0, 'MONTENEGRO': 0.0, 'SERBIA': 0.0, 'AZERBAIJAN': 0.0, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'SLOVAKIA': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_ARMENIA
# state_abrev =  ARMENIA
# ARMENIA ARMENIA
# state flux =  [{'ARMENIA': 0.0, 'CROATIA': 30331.275413711584, 'DENMARK': 30331.275413711584, 'FINLAND': 24978.697399527187, 'FRANCE': 130246.06501182033, 'GERMANY': 19626.11938534279, 'GREECE': 260492.13002364067, 'LATVIA': 8920.963356973994, 'LITHUANIA': 10705.156028368794, 'MALTA': 151656.37706855792, 'MOLDOVA': 144519.60638297873, 'NORWAY': 107051.56028368796, 'ROMANIA': 46389.00945626477, 'RUSSIA': 387169.80969267135, 'SPAIN': 23194.504728132386, 'SWEDEN': 178419.26713947993, 'SWITZERLAND': 74936.09219858157, 'TURKEY': 28547.082742316783, 'UKRAINE': 181987.6524822695, 'ALBANIA': 10705.156028368794, 'ANDORRA': 0.0, 'BELARUS': 101698.98226950354, 'BELGIUM': 64230.936170212764, 'BULGARIA': 55309.97281323877, 'CYPRUS': 215887.3132387707, 'ESTONIA': 42820.624113475176, 'ICELAND': 46389.00945626477, 'MONACO': 0.0, 'POLAND': 24978.697399527187, 'PORTUGAL': 87425.44089834516, 'SLOVENIA': 10705.156028368794, 'GEORGIA': 251571.16666666666, 'HUNGARY': 17841.92671394799, 'SERBIA': 46389.00945626477, 'AUSTRIA': 53525.78014184398, 'MONTENEGRO': 78504.47754137116, 'AZERBAIJAN': 5352.578014184397, 'ITALY': 66015.12884160757, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'SLOVAKIA': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 48806.95958155016, 'ANDORRA': 4306.4964336661915, 'ARMENIA': 0.0, 'BELARUS': 132065.89063242986, 'BELGIUM': 180872.85021398, 'BULGARIA': 157904.86923442702, 'CROATIA': 17225.985734664766, 'CYPRUS': 159340.36804564908, 'DENMARK': 11483.99048977651, 'ESTONIA': 21532.482168330956, 'FINLAND': 41629.465525439846, 'FRANCE': 203840.83119353303, 'GERMANY': 84694.42986210177, 'GREECE': 226808.81217308607, 'ICELAND': 35887.47028055159, 'LATVIA': 44500.46314788397, 'LITHUANIA': 14354.988112220637, 'MALTA': 74645.93818354732, 'MOLDOVA': 126323.8953875416, 'MONACO': 0.0, 'NORWAY': 10048.491678554446, 'POLAND': 97613.91916310032, 'PORTUGAL': 28709.976224441274, 'ROMANIA': 80387.93342843557, 'RUSSIA': 268438.2776985259, 'SLOVENIA': 25838.978601997147, 'SPAIN': 173695.3561578697, 'SWEDEN': 67468.444127437, 'SWITZERLAND': 10048.491678554446, 'TURKEY': 107662.41084165478, 'UKRAINE': 111968.90727532098, 'AUSTRIA': 54548.95482643842, 'GEORGIA': 209582.8264384213, 'HUNGARY': 40193.966714217786, 'MONTENEGRO': 97613.91916310032, 'SERBIA': 22967.98097955302, 'AZERBAIJAN': 0.0, 'SLOVAKIA': 10048.491678554446, 'ITALY': 15790.4869234427, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_AUSTRIA
# state_abrev =  AUSTRIA
# AUSTRIA AUSTRIA
# state flux =  [{'AUSTRIA': 0.0, 'BELGIUM': 271281.4623032311, 'FINLAND': 130356.02734051367, 'FRANCE': 436868.8483844242, 'GERMANY': 454484.5277547639, 'GREECE': 200818.74482187242, 'ITALY': 373452.4026512013, 'LUXEMBOURG': 165587.38608119305, 'MONACO': 49323.90223695112, 'NORWAY': 281850.86992543493, 'PORTUGAL': 137402.29908864954, 'SPAIN': 239573.2394366197, 'SWITZERLAND': 560178.603976802, 'SWEDEN': 658826.4084507042, 'DENMARK': 398114.3537696769, 'TURKEY': 246619.5111847556, 'CYPRUS': 112740.34797017399, 'ICELAND': 179679.9295774648, 'MALTA': 250142.64705882352, 'CROATIA': 412206.8972659486, 'SLOVENIA': 123309.7555923778, 'ESTONIA': 193772.47307373656, 'HUNGARY': 278327.734051367, 'LITHUANIA': 10569.407622203811, 'POLAND': 207865.0165700083, 'ROMANIA': 302989.68516984256, 'RUSSIA': 373452.4026512013, 'SLOVAKIA': 10569.407622203811, 'LATVIA': 84555.26097763049, 'UKRAINE': 105694.07622203811, 'ALBANIA': 211388.15244407623, 'ANDORRA': 0.0, 'BELARUS': 88078.39685169843, 'MOLDOVA': 119786.61971830986, 'BULGARIA': 250142.64705882352, 'ARMENIA': 133879.1632145816, 'GEORGIA': 7046.271748135874, 'SERBIA': 285374.00579950295, 'MONTENEGRO': 0.0, 'AZERBAIJAN': 158541.1143330572, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'AUSTRIA': 0.0, 'BELGIUM': 498494.56375838927, 'FINLAND': 369114.2953020134, 'FRANCE': 384335.50335570466, 'GERMANY': 422388.5234899329, 'GREECE': 365308.9932885906, 'ITALY': 293008.25503355707, 'LUXEMBOURG': 53274.22818791946, 'MONACO': 38053.02013422819, 'NORWAY': 254955.23489932888, 'PORTUGAL': 296813.55704697984, 'SPAIN': 369114.2953020134, 'SWITZERLAND': 460441.5436241611, 'SWEDEN': 384335.50335570466, 'DENMARK': 422388.5234899329, 'TURKEY': 270176.44295302016, 'CYPRUS': 220707.51677852348, 'ICELAND': 350087.7852348993, 'MALTA': 167433.28859060403, 'CROATIA': 167433.28859060403, 'SLOVENIA': 285397.6510067114, 'ESTONIA': 331061.27516778524, 'HUNGARY': 216902.21476510065, 'LITHUANIA': 270176.44295302016, 'POLAND': 152212.08053691275, 'ROMANIA': 163627.9865771812, 'RUSSIA': 102743.1543624161, 'SLOVAKIA': 41858.32214765101, 'LATVIA': 121769.66442953021, 'UKRAINE': 60884.832214765105, 'ALBANIA': 57079.530201342284, 'ANDORRA': 30442.416107382553, 'BELARUS': 121769.66442953021, 'BULGARIA': 285397.6510067114, 'MOLDOVA': 98937.85234899328, 'ARMENIA': 114159.06040268457, 'GEORGIA': 140796.1744966443, 'MONTENEGRO': 11415.906040268455, 'SERBIA': 64690.13422818792, 'AZERBAIJAN': 45663.62416107382, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_AZERBAIJAN
# state_abrev =  AZERBAIJAN
# AZERBAIJAN AZERBAIJAN
# state flux =  [{'ALBANIA': 449071.4578005115, 'ARMENIA': 0.0, 'AZERBAIJAN': 0.0, 'CROATIA': 99793.65728900257, 'DENMARK': 106030.76086956522, 'FINLAND': 37422.62148337596, 'FRANCE': 56133.93222506394, 'GEORGIA': 555102.2186700767, 'GERMANY': 37422.62148337596, 'GREECE': 604999.047314578, 'ICELAND': 43659.72506393862, 'LATVIA': 193350.21099744245, 'NORWAY': 324329.38618925837, 'POLAND': 130979.17519181586, 'PORTUGAL': 249484.1432225064, 'ROMANIA': 455308.56138107413, 'RUSSIA': 1135152.8516624041, 'SERBIA': 74845.24296675192, 'SPAIN': 24948.414322250643, 'SWEDEN': 224535.72890025575, 'TURKEY': 449071.4578005115, 'UKRAINE': 860720.2941176471, 'ANDORRA': 0.0, 'BELGIUM': 106030.76086956522, 'ESTONIA': 162164.69309462918, 'MOLDOVA': 580050.6329923274, 'MONTENEGRO': 212061.52173913043, 'SLOVENIA': 124742.0716112532, 'LITHUANIA': 180876.00383631713, 'MALTA': 555102.2186700767, 'CYPRUS': 243247.03964194373, 'HUNGARY': 430360.14705882355, 'SLOVAKIA': 0.0, 'BELARUS': 343040.6969309463, 'BULGARIA': 286906.76470588235, 'SWITZERLAND': 149690.48593350383, 'AUSTRIA': 74845.24296675192, 'ITALY': 193350.21099744245, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'MONACO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 346637.4507531866, 'ANDORRA': 56516.97566628042, 'ARMENIA': 11303.395133256083, 'AZERBAIJAN': 0.0, 'BELARUS': 248674.69293163382, 'BELGIUM': 139408.53997682504, 'BULGARIA': 263745.88644264196, 'CROATIA': 275049.281575898, 'CYPRUS': 421993.4183082271, 'DENMARK': 146944.1367323291, 'ESTONIA': 180854.32213209732, 'FINLAND': 90427.16106604866, 'FRANCE': 180854.32213209732, 'GEORGIA': 625454.5307068366, 'GERMANY': 75355.96755504055, 'GREECE': 429529.0150637312, 'HUNGARY': 414457.82155272306, 'ICELAND': 226067.90266512168, 'LATVIA': 241139.09617612977, 'LITHUANIA': 391851.0312862109, 'MALTA': 467206.9988412515, 'MOLDOVA': 621686.7323290845, 'MONTENEGRO': 331566.2572421785, 'NORWAY': 188389.91888760138, 'POLAND': 252442.49130938583, 'PORTUGAL': 210996.70915411355, 'ROMANIA': 335334.0556199305, 'RUSSIA': 704578.2966396292, 'SERBIA': 79123.76593279258, 'SLOVENIA': 162015.33024333717, 'SPAIN': 162015.33024333717, 'SWEDEN': 195925.51564310546, 'SWITZERLAND': 86659.36268829665, 'TURKEY': 316495.0637311703, 'UKRAINE': 440832.4101969872, 'SLOVAKIA': 109266.1529548088, 'AUSTRIA': 169550.92699884126, 'ITALY': 154479.73348783315, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'MONACO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_BELARUS
# state_abrev =  BELARUS
# BELARUS BELARUS
# state flux =  [{'ALBANIA': 113474.251497006, 'AUSTRIA': 151299.00199600798, 'BELGIUM': 250588.97205588824, 'CROATIA': 170211.37724550898, 'CYPRUS': 193851.84630738522, 'FRANCE': 52009.03193612774, 'GERMANY': 75649.50099800399, 'GREECE': 297869.9101796407, 'ICELAND': 255317.06586826348, 'MALTA': 212764.22155688622, 'NORWAY': 501177.9441117765, 'POLAND': 283685.628742515, 'ROMANIA': 127658.53293413174, 'RUSSIA': 940890.6686626746, 'SPAIN': 37824.750499001995, 'SWEDEN': 368791.31736526947, 'TURKEY': 85105.68862275449, 'UKRAINE': 1016540.1696606787, 'ANDORRA': 18912.375249500998, 'BELARUS': 47280.938123752494, 'DENMARK': 170211.37724550898, 'ESTONIA': 349878.94211576844, 'FINLAND': 127658.53293413174, 'LATVIA': 198579.94011976046, 'LITHUANIA': 477537.4750499002, 'MONACO': 0.0, 'PORTUGAL': 160755.1896207585, 'SLOVENIA': 146570.90818363274, 'SWITZERLAND': 137114.72055888225, 'HUNGARY': 174939.47105788422, 'MOLDOVA': 491721.75648702594, 'BULGARIA': 368791.31736526947, 'ARMENIA': 434984.6307385229, 'GEORGIA': 411344.16167664673, 'SERBIA': 222220.4091816367, 'MONTENEGRO': 23640.469061876247, 'AZERBAIJAN': 312054.1916167665, 'SLOVAKIA': 14184.28143712575, 'ITALY': 52009.03193612774, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 100388.1825590872, 'ANDORRA': 0.0, 'AUSTRIA': 193054.19722901387, 'BELARUS': 77221.67889160554, 'BELGIUM': 30888.671556642214, 'CROATIA': 131276.85411572942, 'CYPRUS': 347497.55501222494, 'DENMARK': 38610.83944580277, 'ESTONIA': 370664.0586797066, 'FINLAND': 108110.35044824776, 'FRANCE': 138999.02200488996, 'GERMANY': 15444.335778321107, 'GREECE': 393830.56234718824, 'ICELAND': 146721.18989405053, 'LATVIA': 409274.8981255093, 'LITHUANIA': 640939.934800326, 'MALTA': 393830.56234718824, 'MONACO': 7722.167889160553, 'NORWAY': 30888.671556642214, 'POLAND': 308886.71556642215, 'PORTUGAL': 115832.51833740831, 'ROMANIA': 108110.35044824776, 'RUSSIA': 687272.9421352893, 'SLOVENIA': 169887.69356153219, 'SPAIN': 54055.17522412388, 'SWEDEN': 30888.671556642214, 'SWITZERLAND': 15444.335778321107, 'TURKEY': 61777.34311328443, 'UKRAINE': 1196936.022819886, 'BULGARIA': 308886.71556642215, 'HUNGARY': 239387.20456397717, 'MOLDOVA': 594606.9274653627, 'ARMENIA': 440163.5696821516, 'GEORGIA': 671828.6063569682, 'MONTENEGRO': 185332.0293398533, 'SERBIA': 193054.19722901387, 'AZERBAIJAN': 424719.23390383046, 'SLOVAKIA': 30888.671556642214, 'ITALY': 61777.34311328443, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_BELGIUM
# state_abrev =  BELGIUM
# BELGIUM BELGIUM
# state flux =  [{'BELGIUM': 0.0, 'FINLAND': 179615.5327754533, 'FRANCE': 609130.9372384937, 'GERMANY': 550560.6548117155, 'ITALY': 363135.75104602514, 'LUXEMBOURG': 206948.33124128313, 'MALTA': 206948.33124128313, 'MONACO': 62474.96792189679, 'NORWAY': 519323.1708507671, 'PORTUGAL': 429515.40446304047, 'SPAIN': 499799.7433751743, 'SWEDEN': 780937.0990237099, 'SWITZERLAND': 464657.5739191074, 'TURKEY': 546655.969316597, 'AUSTRIA': 511513.79986053, 'GREECE': 613035.6227336122, 'DENMARK': 445134.1464435146, 'CYPRUS': 370945.12203626224, 'ICELAND': 382659.17852161784, 'CROATIA': 74189.02440725244, 'SLOVENIA': 85903.0808926081, 'HUNGARY': 203043.64574616455, 'POLAND': 242090.50069735007, 'RUSSIA': 335802.95258019527, 'ESTONIA': 195234.27475592747, 'SLOVAKIA': 15618.741980474197, 'ROMANIA': 292851.4121338912, 'LITHUANIA': 124949.93584379357, 'LATVIA': 187424.90376569037, 'UKRAINE': 226471.7587168759, 'ALBANIA': 245995.1861924686, 'ANDORRA': 0.0, 'BELARUS': 15618.741980474197, 'MOLDOVA': 148378.04881450487, 'BULGARIA': 199138.96025104605, 'ARMENIA': 491990.3723849372, 'GEORGIA': 124949.93584379357, 'SERBIA': 101521.82287308227, 'MONTENEGRO': 0.0, 'AZERBAIJAN': 144473.36331938635, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'BELGIUM': 0.0, 'FINLAND': 532262.6887966805, 'FRANCE': 697010.663900415, 'GERMANY': 481571.00414937764, 'ITALY': 270355.65145228215, 'LUXEMBOURG': 202766.73858921163, 'MALTA': 156299.3609958506, 'MONACO': 109831.98340248964, 'NORWAY': 397084.86307053943, 'PORTUGAL': 675889.1286307054, 'SPAIN': 582954.3734439834, 'SWEDEN': 397084.86307053943, 'SWITZERLAND': 350617.48547717836, 'TURKEY': 266131.34439834027, 'AUSTRIA': 325271.643153527, 'GREECE': 346393.17842323653, 'DENMARK': 506916.846473029, 'CYPRUS': 308374.41493775934, 'ICELAND': 342168.87136929465, 'CROATIA': 63364.605809128625, 'SLOVENIA': 342168.87136929465, 'HUNGARY': 156299.3609958506, 'POLAND': 443552.24066390045, 'RUSSIA': 266131.34439834027, 'ESTONIA': 392860.55601659755, 'SLOVAKIA': 114056.29045643154, 'ROMANIA': 168972.28215767635, 'LITHUANIA': 270355.65145228215, 'LATVIA': 329495.9502074689, 'UKRAINE': 173196.58921161827, 'ALBANIA': 177420.89626556018, 'ANDORRA': 33794.45643153527, 'BELARUS': 223888.27385892117, 'BULGARIA': 219663.96680497928, 'MOLDOVA': 164747.97510373444, 'ARMENIA': 152075.05394190873, 'GEORGIA': 223888.27385892117, 'MONTENEGRO': 76037.52697095436, 'SERBIA': 185869.51037344398, 'AZERBAIJAN': 71813.21991701245, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_BOSNIA
# state_abrev =  BOSNIA
# BOSNIA BOSNIA
# state flux =  [{'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_BULGARIA
# state_abrev =  BULGARIA
# BULGARIA BULGARIA
# state flux =  [{'ALBANIA': 109918.95522388059, 'CROATIA': 188432.4946695096, 'CYPRUS': 397801.9331911869, 'DENMARK': 151792.84292821607, 'FRANCE': 88982.01137171287, 'GERMANY': 109918.95522388059, 'GREECE': 586234.4278606965, 'HUNGARY': 246009.09026297083, 'LATVIA': 5234.235963041933, 'MALTA': 136090.13503909027, 'MOLDOVA': 209369.43852167734, 'NORWAY': 130855.89907604834, 'ROMANIA': 277414.5060412225, 'RUSSIA': 345459.57356076763, 'SPAIN': 47108.1236673774, 'SWEDEN': 172729.78678038382, 'SWITZERLAND': 57576.595593461265, 'TURKEY': 502486.65245202556, 'UKRAINE': 497252.41648898367, 'ANDORRA': 0.0, 'AUSTRIA': 392567.69722814497, 'BELARUS': 209369.43852167734, 'BELGIUM': 272180.27007818053, 'BULGARIA': 0.0, 'ESTONIA': 78513.539445629, 'FINLAND': 88982.01137171287, 'ICELAND': 57576.595593461265, 'LITHUANIA': 230306.38237384506, 'MONACO': 0.0, 'POLAND': 99450.48329779673, 'PORTUGAL': 73279.30348258706, 'SLOVENIA': 73279.30348258706, 'ARMENIA': 575765.9559346127, 'GEORGIA': 193666.73063255154, 'SERBIA': 361162.2814498934, 'MONTENEGRO': 0.0, 'AZERBAIJAN': 366396.5174129353, 'ITALY': 31405.415778251598, 'SLOVAKIA': 0.0, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 347124.8848419925, 'ANDORRA': 0.0, 'AUSTRIA': 280066.6684520621, 'BELARUS': 307678.875200857, 'BELGIUM': 201174.6491697911, 'BULGARIA': 0.0, 'CROATIA': 236676.05784681306, 'CYPRUS': 473352.1156936261, 'DENMARK': 209063.85109801823, 'ESTONIA': 220897.65399035887, 'FINLAND': 173562.44242099626, 'FRANCE': 272177.466523835, 'GERMANY': 252454.46170326727, 'GREECE': 280066.6684520621, 'HUNGARY': 284011.26941617567, 'ICELAND': 59169.014461703264, 'LATVIA': 118338.02892340653, 'LITHUANIA': 185396.24531333693, 'MALTA': 327401.88002142473, 'MOLDOVA': 201174.6491697911, 'MONACO': 0.0, 'NORWAY': 315568.0771290841, 'POLAND': 122282.6298875201, 'PORTUGAL': 161728.6395286556, 'ROMANIA': 181451.64434922335, 'RUSSIA': 15778.403856454204, 'SLOVENIA': 205119.25013390466, 'SPAIN': 319512.67809319764, 'SWEDEN': 98615.02410283878, 'SWITZERLAND': 177507.0433851098, 'TURKEY': 193285.44724156402, 'UKRAINE': 157784.03856454205, 'ARMENIA': 122282.6298875201, 'GEORGIA': 134116.43277986074, 'MONTENEGRO': 114393.42795929298, 'SERBIA': 299789.6732726299, 'AZERBAIJAN': 181451.64434922335, 'ITALY': 134116.43277986074, 'SLOVAKIA': 0.0, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_CROATIA
# state_abrev =  CROATIA
# CROATIA CROATIA
# state flux =  [{'AUSTRIA': 95412.50809716599, 'BELGIUM': 32526.991396761132, 'CROATIA': 0.0, 'CYPRUS': 188656.55010121458, 'DENMARK': 138781.82995951417, 'FINLAND': 49874.72014170041, 'FRANCE': 104086.37246963562, 'GERMANY': 75896.31325910932, 'GREECE': 156129.55870445343, 'ICELAND': 39032.38967611336, 'ITALY': 138781.82995951417, 'LUXEMBOURG': 0.0, 'MALTA': 245036.6685222672, 'NORWAY': 158298.02479757086, 'PORTUGAL': 88907.10981781378, 'SLOVENIA': 292742.92257085023, 'SPAIN': 78064.77935222672, 'SWEDEN': 127939.49949392713, 'SWITZERLAND': 121434.1012145749, 'TURKEY': 121434.1012145749, 'ESTONIA': 62885.516700404856, 'HUNGARY': 242868.2024291498, 'LITHUANIA': 86738.64372469636, 'POLAND': 30358.525303643724, 'ROMANIA': 58548.58451417004, 'RUSSIA': 245036.6685222672, 'SLOVAKIA': 17347.72874493927, 'LATVIA': 67222.44888663967, 'UKRAINE': 177814.21963562755, 'ALBANIA': 214678.14321862347, 'ANDORRA': 4336.932186234818, 'BELARUS': 36863.92358299595, 'MONACO': 0.0, 'MOLDOVA': 62885.516700404856, 'BULGARIA': 130107.96558704453, 'ARMENIA': 26021.593117408906, 'GEORGIA': 34695.45748987854, 'SERBIA': 338280.7105263158, 'MONTENEGRO': 36863.92358299595, 'AZERBAIJAN': 158298.02479757086, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'AUSTRIA': 306250.46609651804, 'BELGIUM': 49732.981673793525, 'CROATIA': 0.0, 'CYPRUS': 141346.36896762368, 'DENMARK': 26175.253512522908, 'FINLAND': 54968.03237629811, 'FRANCE': 88995.86194257789, 'GERMANY': 217254.60415394013, 'GREECE': 104701.01405009163, 'ICELAND': 115171.1154551008, 'ITALY': 15705.152107513744, 'LUXEMBOURG': 0.0, 'MALTA': 238194.80696395846, 'NORWAY': 86378.3365913256, 'PORTUGAL': 107318.53940134392, 'SLOVENIA': 481624.6646304215, 'SPAIN': 91613.38729383016, 'SWEDEN': 68055.65913255957, 'SWITZERLAND': 264370.06047648133, 'TURKEY': 143963.89431887597, 'ESTONIA': 70673.18448381184, 'HUNGARY': 115171.1154551008, 'LITHUANIA': 70673.18448381184, 'POLAND': 62820.60843005498, 'ROMANIA': 99465.96334758705, 'RUSSIA': 86378.3365913256, 'SLOVAKIA': 70673.18448381184, 'LATVIA': 62820.60843005498, 'UKRAINE': 159669.04642638974, 'ALBANIA': 99465.96334758705, 'ANDORRA': 0.0, 'BELARUS': 94230.91264508247, 'MONACO': 41880.405620036654, 'BULGARIA': 94230.91264508247, 'MOLDOVA': 49732.981673793525, 'ARMENIA': 44497.930971288944, 'GEORGIA': 28792.7788637752, 'MONTENEGRO': 157051.52107513745, 'SERBIA': 232959.75626145388, 'AZERBAIJAN': 41880.405620036654, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_CYPRUS
# state_abrev =  CYPRUS
# CYPRUS CYPRUS
# state flux =  [{'AUSTRIA': 22440.595774160025, 'BELGIUM': 28244.198129546243, 'CYPRUS': 0.0, 'DENMARK': 31339.452719085555, 'FINLAND': 17023.90024246623, 'FRANCE': 39464.49601662626, 'GERMANY': 21279.875303082787, 'GREECE': 180685.48666435745, 'LUXEMBOURG': 12381.018358157256, 'NORWAY': 35208.5209560097, 'PORTUGAL': 22827.502597852443, 'SPAIN': 47589.539314166956, 'SWEDEN': 63065.812261863524, 'SWITZERLAND': 28244.198129546243, 'TURKEY': 4642.881884308971, 'ITALY': 46041.9120193973, 'ICELAND': 18184.62071354347, 'MALTA': 27857.291305853825, 'CROATIA': 20892.96847939037, 'SLOVENIA': 10059.57741600277, 'ESTONIA': 18184.62071354347, 'HUNGARY': 17797.713889851057, 'LITHUANIA': 17410.807066158643, 'POLAND': 8125.043297540699, 'ROMANIA': 35208.5209560097, 'RUSSIA': 65387.253204018016, 'SLOVAKIA': 0.0, 'LATVIA': 9285.763768617942, 'UKRAINE': 41399.030135088324, 'ALBANIA': 11607.204710772428, 'ANDORRA': 0.0, 'BELARUS': 17410.807066158643, 'MONACO': 1547.627294769657, 'MOLDOVA': 22440.595774160025, 'BULGARIA': 46428.81884308971, 'ARMENIA': 42946.65742985799, 'GEORGIA': 22053.688950467615, 'SERBIA': 16636.993418773814, 'MONTENEGRO': 2321.4409421544856, 'AZERBAIJAN': 43333.564253550394, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'AUSTRIA': 13337.313432835821, 'BELGIUM': 39595.14925373134, 'CYPRUS': 0.0, 'DENMARK': 33343.28358208955, 'FINLAND': 45013.432835820895, 'FRANCE': 23757.089552238805, 'GERMANY': 23340.29850746269, 'GREECE': 186722.3880597015, 'LUXEMBOURG': 3334.3283582089553, 'NORWAY': 27925.0, 'PORTUGAL': 25841.0447761194, 'SPAIN': 46263.80597014925, 'SWEDEN': 41262.31343283582, 'SWITZERLAND': 28341.791044776117, 'TURKEY': 4167.910447761194, 'ITALY': 27091.417910447763, 'ICELAND': 42929.4776119403, 'MALTA': 49598.13432835821, 'CROATIA': 36260.82089552239, 'SLOVENIA': 20422.761194029852, 'ESTONIA': 33760.07462686567, 'HUNGARY': 18338.805970149253, 'LITHUANIA': 14170.895522388058, 'POLAND': 14170.895522388058, 'ROMANIA': 22923.507462686568, 'RUSSIA': 27508.208955223883, 'SLOVAKIA': 7502.238805970149, 'LATVIA': 13337.313432835821, 'UKRAINE': 11670.149253731344, 'ALBANIA': 36260.82089552239, 'ANDORRA': 2500.7462686567164, 'BELARUS': 17088.432835820895, 'MONACO': 10002.985074626866, 'BULGARIA': 31676.119402985078, 'MOLDOVA': 13337.313432835821, 'ARMENIA': 50431.71641791045, 'GEORGIA': 26257.83582089552, 'MONTENEGRO': 16671.641791044774, 'SERBIA': 14587.686567164179, 'AZERBAIJAN': 16254.850746268656, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_CZECH
# state_abrev =  CZECH
# CZECH CZECH
# state flux =  [{'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_DENMARK
# state_abrev =  DENMARK
# DENMARK DENMARK
# state flux =  [{'AUSTRIA': 229874.86268766018, 'BELGIUM': 248513.36506774073, 'DENMARK': 0.0, 'FINLAND': 132540.46136946173, 'FRANCE': 144966.1296228488, 'GERMANY': 395550.43939948734, 'GREECE': 86979.67777370926, 'ITALY': 51773.61772244599, 'LUXEMBOURG': 66270.23068473086, 'MONACO': 28993.225924569753, 'NORWAY': 557084.126693519, 'PORTUGAL': 64199.28597583302, 'SPAIN': 76624.95422922006, 'SWEDEN': 905002.8377883559, 'SWITZERLAND': 242300.5309410472, 'TURKEY': 186385.02380080556, 'CYPRUS': 165675.57671182716, 'ICELAND': 333422.0981325522, 'MALTA': 173959.35554741853, 'CROATIA': 20709.447088978395, 'SLOVENIA': 45560.78359575247, 'HUNGARY': 103547.23544489198, 'POLAND': 53844.56243134383, 'RUSSIA': 180172.18967411204, 'ESTONIA': 178101.2449652142, 'LITHUANIA': 109760.0695715855, 'LATVIA': 144966.1296228488, 'ROMANIA': 132540.46136946173, 'ALBANIA': 64199.28597583302, 'UKRAINE': 165675.57671182716, 'ANDORRA': 0.0, 'BELARUS': 10354.723544489198, 'MOLDOVA': 82837.78835591358, 'BULGARIA': 109760.0695715855, 'ARMENIA': 16567.557671182716, 'GEORGIA': 10354.723544489198, 'SERBIA': 45560.78359575247, 'MONTENEGRO': 10354.723544489198, 'AZERBAIJAN': 80766.84364701575, 'SLOVAKIA': 0.0, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'AUSTRIA': 195503.13551544814, 'BELGIUM': 197233.25175894768, 'DENMARK': 0.0, 'FINLAND': 188582.67054145, 'FRANCE': 212804.29795044355, 'GERMANY': 254327.08779443253, 'GREECE': 77855.23095747936, 'ITALY': 179932.0893239523, 'LUXEMBOURG': 44983.022330988075, 'MONACO': 57093.836035484856, 'NORWAY': 503463.8268583665, 'PORTUGAL': 131488.83450596512, 'SPAIN': 160900.81064545733, 'SWEDEN': 500003.5943713674, 'SWITZERLAND': 121108.13704496787, 'TURKEY': 55363.71979198532, 'CYPRUS': 140139.41572346285, 'ICELAND': 429068.82838788617, 'MALTA': 159170.6944019578, 'CROATIA': 110727.43958397064, 'SLOVENIA': 211074.18170694404, 'HUNGARY': 193773.0192719486, 'POLAND': 129758.71826246558, 'RUSSIA': 105537.09085347202, 'ESTONIA': 235295.8091159376, 'LITHUANIA': 122838.25328846741, 'LATVIA': 214534.41419394308, 'ROMANIA': 145329.76445396146, 'ALBANIA': 29411.9761394922, 'ANDORRA': 31142.09238299174, 'BELARUS': 62284.18476598348, 'UKRAINE': 88235.9284184766, 'BULGARIA': 50173.371061486694, 'MOLDOVA': 50173.371061486694, 'ARMENIA': 29411.9761394922, 'GEORGIA': 51903.487304986236, 'MONTENEGRO': 53633.60354848577, 'SERBIA': 74394.99847048028, 'AZERBAIJAN': 29411.9761394922, 'SLOVAKIA': 27681.85989599266, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_ESTONIA
# state_abrev =  ESTONIA
# ESTONIA ESTONIA
# state flux =  [{'AUSTRIA': 47237.43442622951, 'CROATIA': 14659.89344262295, 'CYPRUS': 43979.680327868846, 'ESTONIA': 0.0, 'FINLAND': 91217.11475409837, 'FRANCE': 27147.95081967213, 'GERMANY': 26062.032786885247, 'GREECE': 17917.647540983606, 'HUNGARY': 58096.614754098366, 'ICELAND': 49409.27049180328, 'LITHUANIA': 57553.65573770492, 'MALTA': 38007.13114754098, 'NORWAY': 82529.77049180328, 'POLAND': 15745.811475409835, 'PORTUGAL': 15745.811475409835, 'ROMANIA': 17917.647540983606, 'RUSSIA': 133024.95901639343, 'SLOVAKIA': 3257.754098360656, 'SPAIN': 7058.467213114754, 'SWEDEN': 118908.02459016393, 'SWITZERLAND': 24433.155737704918, 'BELGIUM': 50495.18852459016, 'SLOVENIA': 16288.770491803278, 'TURKEY': 7601.426229508196, 'DENMARK': 73842.4262295082, 'ITALY': 15202.852459016392, 'LATVIA': 71127.63114754097, 'UKRAINE': 61354.36885245902, 'ALBANIA': 1628.877049180328, 'ANDORRA': 4343.672131147541, 'BELARUS': 26062.032786885247, 'MONACO': 1085.9180327868853, 'MOLDOVA': 11402.139344262296, 'BULGARIA': 30405.704918032785, 'ARMENIA': 8144.385245901639, 'GEORGIA': 22804.27868852459, 'SERBIA': 7058.467213114754, 'MONTENEGRO': 0.0, 'AZERBAIJAN': 26062.032786885247, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'AUSTRIA': 33532.02945236999, 'CROATIA': 17680.524620340544, 'CYPRUS': 28654.643350207083, 'ESTONIA': 0.0, 'FINLAND': 124373.34560515416, 'FRANCE': 45115.8214450069, 'GERMANY': 31093.33640128854, 'GREECE': 34141.70271514036, 'HUNGARY': 33532.02945236999, 'ICELAND': 62796.34606534745, 'LITHUANIA': 85963.93005062126, 'MALTA': 23167.583985273814, 'NORWAY': 38409.415554532905, 'POLAND': 40848.10860561436, 'PORTUGAL': 56699.613437643806, 'ROMANIA': 10364.44546709618, 'RUSSIA': 39019.08881730327, 'SLOVAKIA': 29264.31661297745, 'SPAIN': 37190.06902899218, 'SWEDEN': 72551.11826967326, 'SWITZERLAND': 14632.158306488725, 'BELGIUM': 30483.66313851818, 'SLOVENIA': 34141.70271514036, 'TURKEY': 13412.811780947997, 'DENMARK': 52431.90059825127, 'ITALY': 20728.89093419236, 'LATVIA': 115837.91992636908, 'UKRAINE': 24996.603773584906, 'ALBANIA': 9754.772204325818, 'ANDORRA': 0.0, 'BELARUS': 45115.8214450069, 'MONACO': 3048.3663138518173, 'BULGARIA': 9145.098941555454, 'MOLDOVA': 31093.33640128854, 'ARMENIA': 14632.158306488725, 'GEORGIA': 28044.970087436723, 'MONTENEGRO': 4877.386102162909, 'SERBIA': 12193.465255407269, 'AZERBAIJAN': 15851.504832029452, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_FAROE
# state_abrev =  FAROE
# FAROE FAROE
# state flux =  [{'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_FINLAND
# state_abrev =  FINLAND
# FINLAND FINLAND
# state flux =  [{'BELGIUM': 236069.63013698632, 'FINLAND': 0.0, 'FRANCE': 228575.3561643836, 'GERMANY': 151759.04794520547, 'ITALY': 290403.11643835617, 'LUXEMBOURG': 103046.26712328766, 'MALTA': 101172.69863013699, 'MONACO': 31850.664383561645, 'NORWAY': 318506.6438356164, 'PORTUGAL': 153632.61643835617, 'SPAIN': 149885.47945205477, 'SWEDEN': 537714.1575342466, 'SWITZERLAND': 267920.29452054796, 'TURKEY': 103046.26712328766, 'AUSTRIA': 181736.14383561644, 'GREECE': 176115.43835616438, 'DENMARK': 204218.96575342465, 'CYPRUS': 202345.39726027398, 'ICELAND': 316633.0753424657, 'CROATIA': 39344.938356164384, 'SLOVENIA': 67448.46575342465, 'ESTONIA': 382207.97260273976, 'HUNGARY': 211713.2397260274, 'LITHUANIA': 52459.91780821918, 'POLAND': 58080.62328767123, 'ROMANIA': 56207.05479452055, 'RUSSIA': 239816.76712328766, 'SLOVAKIA': 3747.1369863013697, 'LATVIA': 73069.17123287672, 'ALBANIA': 58080.62328767123, 'UKRAINE': 80563.44520547945, 'ANDORRA': 9367.842465753423, 'BELARUS': 26229.95890410959, 'MOLDOVA': 61827.760273972606, 'BULGARIA': 82437.01369863014, 'ARMENIA': 54333.48630136987, 'GEORGIA': 37471.36986301369, 'SERBIA': 71195.60273972603, 'MONTENEGRO': 5620.7054794520545, 'AZERBAIJAN': 44965.643835616436, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'BELGIUM': 130663.40602284529, 'FINLAND': 0.0, 'FRANCE': 142025.44132917965, 'GERMANY': 232921.72377985463, 'ITALY': 79534.24714434061, 'LUXEMBOURG': 59650.68535825545, 'MALTA': 99417.80893042574, 'MONACO': 76693.73831775702, 'NORWAY': 417554.7975077881, 'PORTUGAL': 147706.4589823468, 'SPAIN': 241443.2502596054, 'SWEDEN': 508451.07995846315, 'SWITZERLAND': 247124.26791277257, 'TURKEY': 113620.35306334372, 'AUSTRIA': 105098.82658359295, 'GREECE': 247124.26791277257, 'DENMARK': 181792.56490134995, 'CYPRUS': 124982.3883696781, 'ICELAND': 465843.44755970925, 'CROATIA': 65331.70301142264, 'SLOVENIA': 88055.77362409138, 'ESTONIA': 477205.4828660436, 'HUNGARY': 102258.31775700934, 'LITHUANIA': 122141.8795430945, 'POLAND': 178952.05607476633, 'ROMANIA': 62491.19418483905, 'RUSSIA': 99417.80893042574, 'SLOVAKIA': 5681.017653167186, 'LATVIA': 127822.89719626168, 'ALBANIA': 62491.19418483905, 'ANDORRA': 139184.93250259606, 'BELARUS': 76693.73831775702, 'UKRAINE': 36926.6147455867, 'BULGARIA': 48288.65005192108, 'MOLDOVA': 62491.19418483905, 'ARMENIA': 39767.123572170305, 'GEORGIA': 2840.508826583593, 'MONTENEGRO': 14202.544132917965, 'SERBIA': 19883.561786085153, 'AZERBAIJAN': 17043.052959501558, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_FRANCE
# state_abrev =  FRANCE
# FRANCE FRANCE
# ...
# compartment name =  COVID_TRANSNISTRIA
# state_abrev =  TRANSNISTRIA
# TRANSNISTRIA TRANSNISTRIA
# state flux =  [{'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_TURKEY
# state_abrev =  TURKEY
# TURKEY TURKEY
# state flux =  [{'BELGIUM': 2893174.2652474106, 'FINLAND': 1836936.0414269275, 'FRANCE': 1745089.239355581, 'GERMANY': 3949412.489067894, 'ITALY': 3490178.478711162, 'LUXEMBOURG': 1194008.426927503, 'MALTA': 4270876.296317606, 'MONACO': 321463.80724971235, 'NORWAY': 2617633.859033372, 'PORTUGAL': 2204323.249712313, 'SPAIN': 5418961.3222094355, 'SWEDEN': 4454569.900460299, 'SWITZERLAND': 2755404.062140391, 'TURKEY': 0.0, 'AUSTRIA': 3260561.473532796, 'DENMARK': 1469548.833141542, 'GREECE': 3719795.4838895286, 'CYPRUS': 459234.0103567319, 'ICELAND': 1561395.6352128885, 'CROATIA': 2525787.0569620254, 'SLOVENIA': 826621.2186421173, 'HUNGARY': 1148085.0258918297, 'POLAND': 367387.2082853855, 'RUSSIA': 2296170.0517836595, 'ESTONIA': 1010314.8227848101, 'SLOVAKIA': 0.0, 'ROMANIA': 2525787.0569620254, 'LITHUANIA': 91846.80207134638, 'LATVIA': 275540.40621403913, 'UKRAINE': 3168714.67146145, 'ALBANIA': 2755404.062140391, 'ANDORRA': 137770.20310701957, 'BELARUS': 367387.2082853855, 'MOLDOVA': 1928782.8434982738, 'BULGARIA': 2250246.650747986, 'ARMENIA': 3444255.077675489, 'GEORGIA': 2985021.067318757, 'SERBIA': 0.0, 'MONTENEGRO': 229617.00517836594, 'AZERBAIJAN': 3857565.6869965475, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'BELGIUM': 5400716.259062349, 'FINLAND': 2121709.9589173514, 'FRANCE': 7329543.494441759, 'GERMANY': 8023921.299178347, 'ITALY': 887260.5282745288, 'LUXEMBOURG': 732954.3494441758, 'MALTA': 3356159.389560174, 'MONACO': 424341.99178347026, 'NORWAY': 2276016.137747704, 'PORTUGAL': 810107.4388593524, 'SPAIN': 2121709.9589173514, 'SWEDEN': 3510465.5683905263, 'SWITZERLAND': 5940787.884968584, 'TURKEY': 0.0, 'AUSTRIA': 2700358.1295311744, 'DENMARK': 3471889.0236829384, 'GREECE': 1388755.6094731756, 'CYPRUS': 462918.5364910585, 'ICELAND': 1195872.8859352344, 'CROATIA': 2160286.50362494, 'SLOVENIA': 694377.8047365878, 'HUNGARY': 1157296.3412276462, 'POLAND': 424341.99178347026, 'RUSSIA': 964413.6176897051, 'ESTONIA': 540071.625906235, 'SLOVAKIA': 115729.63412276462, 'ROMANIA': 4127690.283711938, 'LITHUANIA': 617224.7153214113, 'LATVIA': 77153.08941517641, 'UKRAINE': 1504485.24359594, 'ALBANIA': 4359149.551957468, 'ANDORRA': 578648.1706138231, 'BELARUS': 694377.8047365878, 'BULGARIA': 3703348.291928468, 'MOLDOVA': 424341.99178347026, 'ARMENIA': 617224.7153214113, 'GEORGIA': 1427332.1541807638, 'MONTENEGRO': 578648.1706138231, 'SERBIA': 115729.63412276462, 'AZERBAIJAN': 2777511.218946351, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_UKRAINE
# state_abrev =  UKRAINE
# UKRAINE UKRAINE
# state flux =  [{'AUSTRIA': 340321.29631728044, 'BELGIUM': 872073.3218130312, 'CROATIA': 1297474.9422096317, 'CYPRUS': 595562.2685552408, 'ESTONIA': 872073.3218130312, 'FRANCE': 808263.0787535411, 'GERMANY': 212700.81019830029, 'GREECE': 744452.835694051, 'ICELAND': 170160.64815864022, 'LITHUANIA': 1254934.7801699718, 'MALTA': 595562.2685552408, 'NORWAY': 1659066.3195467424, 'POLAND': 1637796.2385269122, 'PORTUGAL': 723182.7546742209, 'ROMANIA': 616832.3495750709, 'RUSSIA': 3062891.6668555243, 'SLOVENIA': 680642.5926345609, 'SPAIN': 127620.48611898017, 'SWEDEN': 1850497.0487252125, 'TURKEY': 829533.1597733712, 'UKRAINE': 0.0, 'ALBANIA': 148890.5671388102, 'ANDORRA': 0.0, 'BELARUS': 3296862.5580736543, 'DENMARK': 1084774.1320113314, 'FINLAND': 276511.0532577904, 'LATVIA': 957153.6458923513, 'MONACO': 0.0, 'SWITZERLAND': 148890.5671388102, 'HUNGARY': 1297474.9422096317, 'MOLDOVA': 2573679.8033994334, 'BULGARIA': 850803.2407932011, 'ARMENIA': 1659066.3195467424, 'GEORGIA': 2446059.317280453, 'SERBIA': 616832.3495750709, 'MONTENEGRO': 255240.97223796035, 'AZERBAIJAN': 2488599.479320113, 'SLOVAKIA': 297781.1342776204, 'ITALY': 191430.72917847027, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'AUSTRIA': 338823.9440433213, 'BELGIUM': 655059.6251504212, 'CROATIA': 926118.7803850783, 'CYPRUS': 1208472.067087846, 'ESTONIA': 1276236.8558965102, 'FRANCE': 338823.9440433213, 'GERMANY': 508235.91606498195, 'GREECE': 768000.9398315283, 'ICELAND': 677647.8880866426, 'LATVIA': 1852237.5607701566, 'MALTA': 960001.1747894103, 'NORWAY': 609883.0992779783, 'POLAND': 1931296.4810469316, 'PORTUGAL': 1321413.381768953, 'ROMANIA': 609883.0992779783, 'RUSSIA': 1671531.457280385, 'SLOVENIA': 1005177.7006618532, 'SPAIN': 960001.1747894103, 'SWEDEN': 621177.230746089, 'TURKEY': 779295.071299639, 'UKRAINE': 0.0, 'ALBANIA': 429176.995788207, 'ANDORRA': 553412.4419374248, 'BELARUS': 2428238.2656438025, 'DENMARK': 903530.5174488568, 'FINLAND': 485647.6531287605, 'LITHUANIA': 1694119.7202166065, 'MONACO': 169411.97202166065, 'SWITZERLAND': 282353.2867027677, 'BULGARIA': 1072942.4894705175, 'HUNGARY': 711530.2824909746, 'MOLDOVA': 2010355.4013237064, 'ARMENIA': 1152001.4097472923, 'GEORGIA': 1773178.6404933815, 'MONTENEGRO': 734118.5454271961, 'SERBIA': 982589.4377256318, 'AZERBAIJAN': 1558590.142599278, 'SLOVAKIA': 338823.9440433213, 'ITALY': 1242354.461492178, 'BOSNIA': 0.0, 'CZECH': 0.0, 'FAROE': 0.0, 'GIBRALTAR': 0.0, 'GUERNSEY': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LIECHTENSTEIN': 0.0, 'LUXEMBOURG': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'SAN': 0.0, 'MAYEN': 0.0, 'TRANSNISTRIA': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_UNITED
# state_abrev =  UNITED
# UNITED UNITED
# state flux =  [{'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_VATICAN
# state_abrev =  VATICAN
# VATICAN VATICAN
# state flux =  [{'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# compartment name =  COVID_ÅLAND
# state_abrev =  ÅLAND
# ÅLAND ÅLAND
# state flux =  [{'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}, {'ALBANIA': 0.0, 'ANDORRA': 0.0, 'ARMENIA': 0.0, 'AUSTRIA': 0.0, 'AZERBAIJAN': 0.0, 'BELARUS': 0.0, 'BELGIUM': 0.0, 'BOSNIA': 0.0, 'BULGARIA': 0.0, 'CROATIA': 0.0, 'CYPRUS': 0.0, 'CZECH': 0.0, 'DENMARK': 0.0, 'ESTONIA': 0.0, 'FAROE': 0.0, 'FINLAND': 0.0, 'FRANCE': 0.0, 'GEORGIA': 0.0, 'GERMANY': 0.0, 'GIBRALTAR': 0.0, 'GREECE': 0.0, 'GUERNSEY': 0.0, 'HUNGARY': 0.0, 'ICELAND': 0.0, 'REPUBLIC': 0.0, 'ISLE': 0.0, 'ITALY': 0.0, 'JERSEY': 0.0, 'KAZAKHSTAN': 0.0, 'KOSOVO': 0.0, 'LATVIA': 0.0, 'LIECHTENSTEIN': 0.0, 'LITHUANIA': 0.0, 'LUXEMBOURG': 0.0, 'MALTA': 0.0, 'MOLDOVA': 0.0, 'MONACO': 0.0, 'MONTENEGRO': 0.0, 'NETHERLANDS': 0.0, 'NORTH': 0.0, 'NORWAY': 0.0, 'POLAND': 0.0, 'PORTUGAL': 0.0, 'ROMANIA': 0.0, 'RUSSIA': 0.0, 'SAN': 0.0, 'SERBIA': 0.0, 'SLOVAKIA': 0.0, 'SLOVENIA': 0.0, 'SPAIN': 0.0, 'MAYEN': 0.0, 'SWEDEN': 0.0, 'SWITZERLAND': 0.0, 'TRANSNISTRIA': 0.0, 'TURKEY': 0.0, 'UKRAINE': 0.0, 'UNITED': 0.0, 'VATICAN': 0.0, 'ÅLAND': 0.0}]
# Number of assigments = 236
#
# Number of assigments = 236
